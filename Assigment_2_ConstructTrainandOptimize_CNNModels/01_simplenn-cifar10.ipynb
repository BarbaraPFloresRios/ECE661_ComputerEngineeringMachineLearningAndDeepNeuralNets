# %% [markdown]
# # Training SimpleNN on CIFAR-10
# In this project, you will use the SimpleNN model to perform image classification on CIFAR-10. CIFAR-10 orginally contains 60K images from 10 categories. We split it into 45K/5K/10K images to serve as train/valiation/test set. We only release the ground-truth labels of training/validation dataset to you.

# %% [markdown]
# ## Step 0: Set up the SimpleNN model
# As you have practiced to implement simple neural networks in Homework 1, we just prepare the implementation for you.

# %%
# import necessary dependencies
import argparse
import os, sys
import time
import datetime
from tqdm import tqdm_notebook as tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
# define the SimpleNN mode;
class SimpleNN(nn.Module):
    def __init__(self):
        super(SimpleNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 8, 5)
        self.conv2 = nn.Conv2d(8, 16, 3)
        self.fc1   = nn.Linear(16*6*6, 120)
        self.fc2   = nn.Linear(120, 84)
        self.fc3   = nn.Linear(84, 10)

    def forward(self, x):
        out = F.relu(self.conv1(x))
        out = F.max_pool2d(out, 2)
        out = F.relu(self.conv2(out))
        out = F.max_pool2d(out, 2)
        out = out.view(out.size(0), -1)
        out = F.relu(self.fc1(out))
        out = F.relu(self.fc2(out))
        out = self.fc3(out)
        return out

# %% [markdown]
# ### Question (a)
# Here is a sanity check to verify the implementation of SimpleNN.
# You need to:
# 1. Write down your code.
# 2. **In the PDF report**, give a brief description on how the code helps you know that SimpleNN is implemented correctly.

# %%
#############################################
# your code here
# sanity check for the correctness of SimpleNN


# Model Definition
net = SimpleNN()

# Test forward pass
data = torch.randn(100,3,32,32)

# Forward pass "data" through "net" to get output "out"
out =  net(data)

# Check output shape
assert(out.detach().cpu().numpy().shape == (100,10))
print("Forward pass successful")

#############################################
# Out:
# Forward pass successful

# %%
#############################################

# 2) Count the total number of parameters of all CONV/FC
# layers and see if it meets your expectation.

print(f"Conv1 weight: {net.conv1.weight.numel()}, Conv1 bias: {net.conv1.bias.numel()}, Total: {net.conv1.weight.numel() + net.conv1.bias.numel()}")
print(f"Conv2 weight: {net.conv2.weight.numel()}, Conv2 bias: {net.conv2.bias.numel()}, Total: {net.conv2.weight.numel() + net.conv2.bias.numel()}")
print(f"FC1 weight: {net.fc1.weight.numel()}, FC1 bias: {net.fc1.bias.numel()}, Total: {net.fc1.weight.numel() + net.fc1.bias.numel()}")
print(f"FC2 weight: {net.fc2.weight.numel()}, FC2 bias: {net.fc2.bias.numel()}, Total: {net.fc2.weight.numel() + net.fc2.bias.numel()}")
print(f"FC3 weight: {net.fc3.weight.numel()}, FC3 bias: {net.fc3.bias.numel()}, Total: {net.fc3.weight.numel() + net.fc3.bias.numel()}")

#############################################
# Out:
# Conv1 weight: 600, Conv1 bias: 8, Total: 608
# Conv2 weight: 1152, Conv2 bias: 16, Total: 1168
# FC1 weight: 69120, FC1 bias: 120, Total: 69240
# FC2 weight: 10080, FC2 bias: 84, Total: 10164
# FC3 weight: 840, FC3 bias: 10, Total: 850

# %% [markdown]
# ## Step 1: Set up preprocessing functions
# Preprocessing is very important as discussed in the lecture.
# You will need to write preprocessing functions with the help of *torchvision.transforms* in this step.
# You can find helpful tutorial/API at [here](https://pytorch.org/vision/stable/transforms.html).

# %% [markdown]
# ### Question (b)
# For the question, you need to:
# 1. Complete the preprocessing code below.
# 2. **In the PDF report**, briefly describe what preprocessing operations you used and what are the purposes of them.
#
# Hint:
# 1. Only two operations are necessary to complete the basic preprocessing here.
# 2. The raw input read from the dataset will be PIL images.
# 3. Data augmentation operations are not mendatory, but feel free to incorporate them if you want.
# 4. Reference value for mean/std of CIFAR-10 images (assuming the pixel values are within [0,1]): mean (RGB-format): (0.4914, 0.4822, 0.4465), std (RGB-format): (0.2023, 0.1994, 0.2010)

# %%
# useful libraries
import torchvision
import torchvision.transforms as transforms

#############################################
# your code here
# specify preprocessing function
transform_train = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.4914, 0.4822, 0.4465), std=(0.2023, 0.1994, 0.2010))])

transform_val = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.4914, 0.4822, 0.4465), std=(0.2023, 0.1994, 0.2010))])
#############################################

# %% [markdown]
# ## Step 2: Set up dataset and dataloader
#
# ### Question (c)
# Set up the train/val datasets and dataloders that are to be used during the training. Check out the [official API](https://pytorch.org/docs/stable/data.html) for more information about **torch.utils.data.DataLoader**.
#
# Here, you need to:
# 1. Complete the code below.

# %%
from google.colab import drive
drive.mount('/content/drive')

import sys
sys.path.append('/content/drive/MyDrive/2023 - Duke/2025-01/ECE661_ComputerEngineeringMachineLearning&DeepNeuralNets/Assigments/HW2')
# Out:
# Mounted at /content/drive

# %%
# do NOT change these
from tools.dataset import CIFAR10
from torch.utils.data import DataLoader

# a few arguments, do NOT change these
DATA_ROOT = "./data"
TRAIN_BATCH_SIZE = 128
VAL_BATCH_SIZE = 100

#############################################
# your code here
# construct dataset
train_set = CIFAR10(
    root=DATA_ROOT,
    mode='train',
    download=True,
    transform=transform_train
)
val_set = CIFAR10(
    root=DATA_ROOT,
    mode='val',
    download=True,
    transform=transform_val
)

# construct dataloader
train_loader = DataLoader(
    train_set,
    batch_size=TRAIN_BATCH_SIZE,
    shuffle=True,
    num_workers=4
)
val_loader = DataLoader(
    val_set,
    batch_size=VAL_BATCH_SIZE,
    shuffle=False,
    num_workers=4
)
#############################################
# Out:
# Downloading https://www.dropbox.com/s/s8orza214q45b23/cifar10_trainval_F22.zip?dl=1 to ./data/cifar10_trainval_F22.zip
# 141746176it [00:05, 25708569.30it/s]
# Extracting ./data/cifar10_trainval_F22.zip to ./data
# Files already downloaded and verified
# Using downloaded and verified file: ./data/cifar10_trainval_F22.zip
# Extracting ./data/cifar10_trainval_F22.zip to ./data
# Files already downloaded and verified

# %% [markdown]
# ## Step 3: Instantiate your SimpleNN model and deploy it to GPU devices.
# ### Question (d)
# You may want to deploy your model to GPU device for efficient training. Please assign your model to GPU if possible. If you are training on a machine without GPUs, please deploy your model to CPUs.
#
# Here, you need to:
# 1. Complete the code below.
# 2. **In the PDF report**, briefly describe how you verify that your model is indeed deployed on GPU. (Hint: check $\texttt{nvidia-smi}$.)

# %%
# !nvidia-smi
# Out:
# Sat Feb 15 23:12:39 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# specify the device for computation
#############################################
# your code here

# GPU check
device = 'cuda' if torch.cuda.is_available() else 'cpu'
if device =='cuda':
    print("Run on GPU...")
else:
    print("Run on CPU...")

# Model Definition
net = SimpleNN()
net = net.to(device)

#############################################
# Out:
# Run on GPU...

# %% [markdown]
# ## Step 4: Set up the loss function and optimizer
# Loss function/objective function is used to provide "feedback" for the neural networks. Typically, we use multi-class cross-entropy as the loss function for classification models. As for the optimizer, we will use SGD with momentum.

# %% [markdown]
# ### Question (e)
# Here, you need to:
# 1. Set up the cross-entropy loss as the criterion. (Hint: there are implemented functions in **torch.nn**)
# 2. Specify a SGD optimizer with momentum. (Hint: there are implemented functions in **torch.optim**)

# %%
import torch.nn as nn
import torch.optim as optim

# hyperparameters, do NOT change right now
# initial learning rate
INITIAL_LR = 0.01

# momentum for optimizer
MOMENTUM = 0.9

# L2 regularization strength
REG = 1e-4

#############################################
# your code here
# create loss function
criterion = nn.CrossEntropyLoss()

# Add optimizer
optimizer = optim.SGD(
    net.parameters(),
    lr=INITIAL_LR,
    momentum=MOMENTUM,
    weight_decay=REG
)
#############################################

# %% [markdown]
# ## Step 5: Start the training process.
#
# ### Question (f)/(g)
# Congratulations! You have completed all of the previous steps and it is time to train our neural network.
#
# Here you need to:
# 1. Complete the training codes.
# 2. Actually perform the training.
#
# Hint: Training a neural network usually repeats the following 4 steps:
#
# **i) Get a batch of data from the dataloader and copy it to your device (GPU).**
#
# **ii) Do a forward pass to get the outputs from the neural network and compute the loss. Be careful about your inputs to the loss function. Are the inputs required to be the logits or softmax probabilities?)**
#
# **iii) Do a backward pass (back-propagation) to compute gradients of all weights with respect to the loss.**
#
# **iiii) Update the model weights with the optimizer.**
#
# You will also need to compute the accuracy of training/validation samples to track your model's performance over each epoch (the accuracy should be increasing as you train for more and more epochs).

# %%
net.eval()
with torch.no_grad():
    inputs, targets = next(iter(train_loader))
    inputs, targets = inputs.to(device), targets.to(device)
    outputs = net(inputs)
    loss = criterion(outputs, targets)

print(f"Initial loss: {loss.item()}")
# Out:
# Initial loss: 2.296983003616333

# %%
# some hyperparameters
# total number of training epochs
EPOCHS = 30

# the folder where the trained model is saved
CHECKPOINT_FOLDER = "./saved_model"

# start the training/validation process
# the process should take about 5 minutes on a GTX 1070-Ti
# if the code is written efficiently.
best_val_acc = 0
current_learning_rate = INITIAL_LR

print("==> Training starts!")
print("="*50)
for i in range(0, EPOCHS):
    #######################
    # your code here
    # switch to train mode
    net.train()
    #######################

    print("Epoch %d:" %i)
    # this help you compute the training accuracy
    total_examples = 0
    correct_examples = 0

    train_loss = 0 # track training loss if you want

    # Train the model for 1 epoch.
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        ####################################
        # your code here
        # copy inputs to device
        inputs = inputs.to(device)
        targets = targets.to(device)

        # compute the output and loss
        outputs = net(inputs)
        loss = criterion(outputs, targets)

        # zero the gradient
        optimizer.zero_grad()

        # backpropagation
        loss.backward()

        # apply gradient and update the weights
        optimizer.step()

        train_loss += loss.item()

        # count the number of correctly predicted samples in the current batch
        max_values, predicted = outputs.max(1)
        total_examples += targets.size(0)
        correct_examples += (predicted == targets).sum().item()
        ####################################

    avg_loss = train_loss / len(train_loader)
    avg_acc = correct_examples / total_examples
    print("Training loss: %.4f, Training accuracy: %.4f" %(avg_loss, avg_acc))

    # Validate on the validation dataset
    #######################
    # your code here
    # switch to eval mode
    net.eval()

    #######################

    # this help you compute the validation accuracy
    total_examples = 0
    correct_examples = 0

    val_loss = 0 # again, track the validation loss if you want

    # disable gradient during validation, which can save GPU memory
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(val_loader):
            ####################################
            # your code here
            # copy inputs to device
            inputs = inputs.to(device)
            targets = targets.to(device)

            # compute the output and loss
            outputs = net(inputs)
            loss = criterion(outputs, targets)

            val_loss += loss.item()

            # count the number of correctly predicted samples in the current batch
            max_values, predicted = outputs.max(1)
            total_examples += targets.size(0)
            correct_examples += (predicted == targets).sum().item()
            ####################################

    avg_loss = val_loss / len(val_loader)
    avg_acc = correct_examples / total_examples
    print("Validation loss: %.4f, Validation accuracy: %.4f" % (avg_loss, avg_acc))

    # save the model checkpoint
    if avg_acc > best_val_acc:
        best_val_acc = avg_acc
        #if not os.path.exists(CHECKPOINT_FOLDER):
        #    os.makedirs(CHECKPOINT_FOLDER)
        #print("Saving ...")
        #state = {'state_dict': net.state_dict(),
        #         'epoch': i,
        #         'lr': current_learning_rate}
        #torch.save(state, os.path.join(CHECKPOINT_FOLDER, 'simplenn.pth'))

    print('')

print("="*50)
print(f"==> Optimization finished! Best validation accuracy: {best_val_acc:.4f}")
# Out:
# ==> Training starts!
# ==================================================
# Epoch 0:
# Training loss: 1.8341, Training accuracy: 0.3288
# Validation loss: 1.5981, Validation accuracy: 0.4156
#
# Epoch 1:
# Training loss: 1.4015, Training accuracy: 0.4932
# Validation loss: 1.3172, Validation accuracy: 0.5304
#
# Epoch 2:
# Training loss: 1.2395, Training accuracy: 0.5577
# Validation loss: 1.1911, Validation accuracy: 0.5784
#
# Epoch 3:
# Training loss: 1.1149, Training accuracy: 0.6055
# Validation loss: 1.1192, Validation accuracy: 0.6052
#
# Epoch 4:
# Training loss: 1.0382, Training accuracy: 0.6348
# Validation loss: 1.0924, Validation accuracy: 0.6196
#
# Epoch 5:
# Training loss: 0.9639, Training accuracy: 0.6607
# Validation loss: 1.0844, Validation accuracy: 0.6238
#
# Epoch 6:
# Training loss: 0.8985, Training accuracy: 0.6850
# Validation loss: 1.0736, Validation accuracy: 0.6406
#
# Epoch 7:
# Training loss: 0.8450, Training accuracy: 0.7010
# Validation loss: 1.0386, Validation accuracy: 0.6406
#
# Epoch 8:
# Training loss: 0.8056, Training accuracy: 0.7173
# Validation loss: 1.0727, Validation accuracy: 0.6424
#
# Epoch 9:
# Training loss: 0.7502, Training accuracy: 0.7369
# Validation loss: 1.0732, Validation accuracy: 0.6462
#
# Epoch 10:
# Training loss: 0.7060, Training accuracy: 0.7507
# Validation loss: 1.0820, Validation accuracy: 0.6366
#
# Epoch 11:
# Training loss: 0.6692, Training accuracy: 0.7636
# Validation loss: 1.0889, Validation accuracy: 0.6564
#
# Epoch 12:
# Training loss: 0.6227, Training accuracy: 0.7808
# Validation loss: 1.1541, Validation accuracy: 0.6368
#
# Epoch 13:
# Training loss: 0.5918, Training accuracy: 0.7922
# Validation loss: 1.1416, Validation accuracy: 0.6554
#
# Epoch 14:
# Training loss: 0.5631, Training accuracy: 0.7995
# Validation loss: 1.1936, Validation accuracy: 0.6476
#
# Epoch 15:
# Training loss: 0.5301, Training accuracy: 0.8120
# Validation loss: 1.2339, Validation accuracy: 0.6444
#
# Epoch 16:
# Training loss: 0.4952, Training accuracy: 0.8241
# Validation loss: 1.2835, Validation accuracy: 0.6552
#
# Epoch 17:
# Training loss: 0.4789, Training accuracy: 0.8294
# Validation loss: 1.2982, Validation accuracy: 0.6404
#
# Epoch 18:
# Training loss: 0.4471, Training accuracy: 0.8380
# Validation loss: 1.3883, Validation accuracy: 0.6424
#
# Epoch 19:
# Training loss: 0.4259, Training accuracy: 0.8470
# Validation loss: 1.3542, Validation accuracy: 0.6402
#
# Epoch 20:
# Training loss: 0.3969, Training accuracy: 0.8566
# Validation loss: 1.4387, Validation accuracy: 0.6338
#
# Epoch 21:
# Training loss: 0.3955, Training accuracy: 0.8597
# Validation loss: 1.5332, Validation accuracy: 0.6364
#
# Epoch 22:
# Training loss: 0.3649, Training accuracy: 0.8702
# Validation loss: 1.5787, Validation accuracy: 0.6278
#
# Epoch 23:
# Training loss: 0.3690, Training accuracy: 0.8695
# Validation loss: 1.6069, Validation accuracy: 0.6260
#
# Epoch 24:
# Training loss: 0.3305, Training accuracy: 0.8815
# Validation loss: 1.7555, Validation accuracy: 0.6288
#
# Epoch 25:
# Training loss: 0.3267, Training accuracy: 0.8841
# Validation loss: 1.9110, Validation accuracy: 0.6090
#
# Epoch 26:
# Training loss: 0.3290, Training accuracy: 0.8822
# Validation loss: 1.8446, Validation accuracy: 0.6270
#
# Epoch 27:
# Training loss: 0.3032, Training accuracy: 0.8907
# Validation loss: 1.8025, Validation accuracy: 0.6308
#
# Epoch 28:
# Training loss: 0.2777, Training accuracy: 0.9012
# Validation loss: 1.9786, Validation accuracy: 0.6222
#
# Epoch 29:
# Training loss: 0.2677, Training accuracy: 0.9052
# Validation loss: 1.9531, Validation accuracy: 0.6130
#
# ==================================================
# ==> Optimization finished! Best validation accuracy: 0.6564

# %% [markdown]
# # Bonus: with learning rate decay
#
# The following code can help you adjust the learning rate during training. You need to figure out how to incorporate this code into your training loop.
# ```python
#     if i % DECAY_EPOCHS == 0 and i != 0:
#         current_learning_rate = current_learning_rate * DECAY
#         for param_group in optimizer.param_groups:
#             param_group['lr'] = current_learning_rate
#         print("Current learning rate has decayed to %f" %current_learning_rate)
# ```

# %%
EPOCHS = 30
DECAY_EPOCHS = 10
DECAY = 0.1
net = SimpleNN()
net = net.to(device)

# Add optimizer
optimizer = optim.SGD(
    net.parameters(),
    lr=INITIAL_LR,
    momentum=MOMENTUM,
    weight_decay=REG
)
# the folder where the trained model is saved
CHECKPOINT_FOLDER = "./saved_model"

# start the training/validation process
# the process should take about 5 minutes on a GTX 1070-Ti
# if the code is written efficiently.
best_val_acc = 0
current_learning_rate = INITIAL_LR

print("==> Training starts!")
print("="*50)
for i in range(0, EPOCHS):
    #######################
    # your code here
    # switch to train mode
    net.train()
    #######################

    print("Epoch %d:" %i)
    # this help you compute the training accuracy
    total_examples = 0
    correct_examples = 0

    train_loss = 0 # track training loss if you want

    # Train the model for 1 epoch.
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        ####################################
        # your code here
        # copy inputs to device
        inputs = inputs.to(device)
        targets = targets.to(device)

        # compute the output and loss
        outputs = net(inputs)
        loss = criterion(outputs, targets)

        # zero the gradient
        optimizer.zero_grad()

        # backpropagation
        loss.backward()

        # apply gradient and update the weights
        optimizer.step()
        train_loss += loss.item()

        # count the number of correctly predicted samples in the current batch
        max_values, predicted = outputs.max(1)
        total_examples += targets.size(0)
        correct_examples += (predicted == targets).sum().item()
        ####################################

    avg_loss = train_loss / len(train_loader)
    avg_acc = correct_examples / total_examples
    print("Training loss: %.4f, Training accuracy: %.4f" %(avg_loss, avg_acc))

    if i % DECAY_EPOCHS == 0 and i != 0:
        current_learning_rate = current_learning_rate * DECAY
        for param_group in optimizer.param_groups:
            param_group['lr'] = current_learning_rate
        print("Current learning rate has decayed to %f" % current_learning_rate)


    # Validate on the validation dataset
    #######################
    # your code here
    # switch to eval mode
    net.eval()

    #######################

    # this help you compute the validation accuracy
    total_examples = 0
    correct_examples = 0

    val_loss = 0 # again, track the validation loss if you want

    # disable gradient during validation, which can save GPU memory
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(val_loader):
            ####################################
            # your code here
            # copy inputs to device
            inputs = inputs.to(device)
            targets = targets.to(device)

            # compute the output and loss
            outputs = net(inputs)
            loss = criterion(outputs, targets)

            val_loss += loss.item()

            # count the number of correctly predicted samples in the current batch
            max_values, predicted = outputs.max(1)
            total_examples += targets.size(0)
            correct_examples += (predicted == targets).sum().item()
            ####################################

    avg_loss = val_loss / len(val_loader)
    avg_acc = correct_examples / total_examples
    print("Validation loss: %.4f, Validation accuracy: %.4f" % (avg_loss, avg_acc))

    # save the model checkpoint
    if avg_acc > best_val_acc:
        best_val_acc = avg_acc
        #if not os.path.exists(CHECKPOINT_FOLDER):
        #    os.makedirs(CHECKPOINT_FOLDER)
        #print("Saving ...")
        #state = {'state_dict': net.state_dict(),
        #         'epoch': i,
        #         'lr': current_learning_rate}
        #torch.save(state, os.path.join(CHECKPOINT_FOLDER, 'simplenn.pth'))

    print('')

print("="*50)
print(f"==> Optimization finished! Best validation accuracy: {best_val_acc:.4f}")
# Out:
# ==> Training starts!
# ==================================================
# Epoch 0:
# Training loss: 1.8677, Training accuracy: 0.3170
# Validation loss: 1.5614, Validation accuracy: 0.4424
#
# Epoch 1:
# Training loss: 1.4266, Training accuracy: 0.4843
# Validation loss: 1.3785, Validation accuracy: 0.5178
#
# Epoch 2:
# Training loss: 1.2446, Training accuracy: 0.5550
# Validation loss: 1.2179, Validation accuracy: 0.5708
#
# Epoch 3:
# Training loss: 1.1139, Training accuracy: 0.6056
# Validation loss: 1.1285, Validation accuracy: 0.6080
#
# Epoch 4:
# Training loss: 1.0218, Training accuracy: 0.6399
# Validation loss: 1.1410, Validation accuracy: 0.6004
#
# Epoch 5:
# Training loss: 0.9499, Training accuracy: 0.6654
# Validation loss: 1.0647, Validation accuracy: 0.6304
#
# Epoch 6:
# Training loss: 0.8775, Training accuracy: 0.6909
# Validation loss: 1.1097, Validation accuracy: 0.6182
#
# Epoch 7:
# Training loss: 0.8317, Training accuracy: 0.7080
# Validation loss: 0.9809, Validation accuracy: 0.6578
#
# Epoch 8:
# Training loss: 0.7688, Training accuracy: 0.7306
# Validation loss: 1.0004, Validation accuracy: 0.6580
#
# Epoch 9:
# Training loss: 0.7252, Training accuracy: 0.7460
# Validation loss: 0.9796, Validation accuracy: 0.6610
#
# Epoch 10:
# Training loss: 0.6871, Training accuracy: 0.7577
# Current learning rate has decayed to 0.001000
# Validation loss: 0.9999, Validation accuracy: 0.6750
#
# Epoch 11:
# Training loss: 0.5091, Training accuracy: 0.8251
# Validation loss: 0.9730, Validation accuracy: 0.6962
#
# Epoch 12:
# Training loss: 0.4735, Training accuracy: 0.8369
# Validation loss: 0.9856, Validation accuracy: 0.6978
#
# Epoch 13:
# Training loss: 0.4542, Training accuracy: 0.8445
# Validation loss: 1.0060, Validation accuracy: 0.6946
#
# Epoch 14:
# Training loss: 0.4401, Training accuracy: 0.8494
# Validation loss: 1.0076, Validation accuracy: 0.6964
#
# Epoch 15:
# Training loss: 0.4276, Training accuracy: 0.8527
# Validation loss: 1.0246, Validation accuracy: 0.6922
#
# Epoch 16:
# Training loss: 0.4152, Training accuracy: 0.8588
# Validation loss: 1.0415, Validation accuracy: 0.6922
#
# Epoch 17:
# Training loss: 0.4036, Training accuracy: 0.8627
# Validation loss: 1.0568, Validation accuracy: 0.6930
#
# Epoch 18:
# Training loss: 0.3926, Training accuracy: 0.8663
# Validation loss: 1.0635, Validation accuracy: 0.6930
#
# Epoch 19:
# Training loss: 0.3831, Training accuracy: 0.8701
# Validation loss: 1.0859, Validation accuracy: 0.6900
#
# Epoch 20:
# Training loss: 0.3720, Training accuracy: 0.8746
# Current learning rate has decayed to 0.000100
# Validation loss: 1.0960, Validation accuracy: 0.6892
#
# Epoch 21:
# Training loss: 0.3463, Training accuracy: 0.8862
# Validation loss: 1.0937, Validation accuracy: 0.6902
#
# Epoch 22:
# Training loss: 0.3427, Training accuracy: 0.8873
# Validation loss: 1.0997, Validation accuracy: 0.6898
#
# Epoch 23:
# Training loss: 0.3412, Training accuracy: 0.8883
# Validation loss: 1.1025, Validation accuracy: 0.6912
#
# Epoch 24:
# Training loss: 0.3397, Training accuracy: 0.8887
# Validation loss: 1.1051, Validation accuracy: 0.6912
#
# Epoch 25:
# Training loss: 0.3388, Training accuracy: 0.8889
# Validation loss: 1.1105, Validation accuracy: 0.6922
#
# Epoch 26:
# Training loss: 0.3373, Training accuracy: 0.8894
# Validation loss: 1.1121, Validation accuracy: 0.6894
#
# Epoch 27:
# Training loss: 0.3361, Training accuracy: 0.8897
# Validation loss: 1.1131, Validation accuracy: 0.6922
#
# Epoch 28:
# Training loss: 0.3350, Training accuracy: 0.8904
# Validation loss: 1.1161, Validation accuracy: 0.6918
#
# Epoch 29:
# Training loss: 0.3339, Training accuracy: 0.8905
# Validation loss: 1.1195, Validation accuracy: 0.6910
#
# ==================================================
# ==> Optimization finished! Best validation accuracy: 0.6978
